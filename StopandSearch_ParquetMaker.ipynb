# %%
import os
import pandas as pd

# %%
def read_files(directory_path, desired_police_stations):
    """
    Read in all CSV files in a directory and concatenate them into a single dataframe.
    
    Args:
        directory_path (str): Path to the directory containing the CSV files.
        desired_police_stations (list): List of desired police station names.
        
    Returns:
        pd.DataFrame: Combined dataframe containing data from all CSV files.
    """
    # Clean desired police station names
    desired_police_stations = [station.lower().replace('-', '') for station in desired_police_stations]
    
    # Get a list of all CSV files in the directory
    file_names = [f for f in os.listdir(directory_path) if f.endswith('.csv')]
    
    # Initialize an empty list to store dataframes
    dfs = []
    # Read each CSV file and append the dataframes to the list
    for file_name in file_names:
        # Extract the police station name from the file name
        police_station = ''.join(file_name.lower().split('-'))[6:-17]
        if police_station in desired_police_stations:
            print(f'Reading file: {file_name}')
            file_path = os.path.join(directory_path, file_name)
            df = pd.read_csv(file_path)
            dfs.append(df)
    
    # Concatenate all dataframes into a single dataframe
    combined_df = pd.concat(dfs, ignore_index=True)
    
    return combined_df


# Set the directory path
directory_path = 'Data/stop_search'

# Define the desired police stations
police_stations = ['metropolitan']

# Read the files and get the combined dataframe
combined_data = read_files(directory_path, police_stations)
# Out:
# Reading file: 2015-04-metropolitan-stop-and-search.csv
# Reading file: 2015-05-metropolitan-stop-and-search.csv
# Reading file: 2015-06-metropolitan-stop-and-search.csv
# Reading file: 2015-07-metropolitan-stop-and-search.csv
# Reading file: 2015-08-metropolitan-stop-and-search.csv
# Reading file: 2015-09-metropolitan-stop-and-search.csv
# Reading file: 2015-10-metropolitan-stop-and-search.csv
# Reading file: 2015-11-metropolitan-stop-and-search.csv
# Reading file: 2015-12-metropolitan-stop-and-search.csv
# Reading file: 2016-01-metropolitan-stop-and-search.csv
# Reading file: 2016-02-metropolitan-stop-and-search.csv
# Reading file: 2016-03-metropolitan-stop-and-search.csv
# Reading file: 2016-04-metropolitan-stop-and-search.csv
# Reading file: 2016-05-metropolitan-stop-and-search.csv
# Reading file: 2016-06-metropolitan-stop-and-search.csv
# Reading file: 2016-07-metropolitan-stop-and-search.csv
# Reading file: 2016-08-metropolitan-stop-and-search.csv
# Reading file: 2016-09-metropolitan-stop-and-search.csv
# Reading file: 2016-10-metropolitan-stop-and-search.csv
# Reading file: 2016-11-metropolitan-stop-and-search.csv
# Reading file: 2016-12-metropolitan-stop-and-search.csv
# Reading file: 2017-01-metropolitan-stop-and-search.csv
# Reading file: 2017-02-metropolitan-stop-and-search.csv
# Reading file: 2017-05-metropolitan-stop-and-search.csv
# Reading file: 2017-06-metropolitan-stop-and-search.csv
# Reading file: 2017-07-metropolitan-stop-and-search.csv
# Reading file: 2017-08-metropolitan-stop-and-search.csv
# Reading file: 2017-09-metropolitan-stop-and-search.csv
# Reading file: 2017-10-metropolitan-stop-and-search.csv
# Reading file: 2017-11-metropolitan-stop-and-search.csv
# Reading file: 2017-12-metropolitan-stop-and-search.csv
# Reading file: 2022-04-metropolitan-stop-and-search.csv
# Reading file: 2022-05-metropolitan-stop-and-search.csv
# Reading file: 2022-06-metropolitan-stop-and-search.csv
# Reading file: 2022-07-metropolitan-stop-and-search.csv
# Reading file: 2022-08-metropolitan-stop-and-search.csv
# Reading file: 2022-09-metropolitan-stop-and-search.csv
# Reading file: 2022-10-metropolitan-stop-and-search.csv
# Reading file: 2022-12-metropolitan-stop-and-search.csv
# Reading file: 2023-01-metropolitan-stop-and-search.csv
# Reading file: 2023-02-metropolitan-stop-and-search.csv
# Reading file: 2023-03-metropolitan-stop-and-search.csv

# %%
combined_data.head(5)
# Out:
#                         Type                       Date
# 0  Person and Vehicle search  2015-03-31T23:00:00+00:00  \
# 1  Person and Vehicle search  2015-03-31T23:00:00+00:00
# 2              Person search  2015-03-31T23:05:00+00:00
# 3              Person search  2015-03-31T23:09:00+00:00
# 4              Person search  2015-03-31T23:15:00+00:00
#
#   Part of a policing operation  Policing operation  Latitude  Longitude
# 0                          NaN                 NaN       NaN        NaN  \
# 1                          NaN                 NaN       NaN        NaN
# 2                          NaN                 NaN       NaN        NaN
# 3                          NaN                 NaN       NaN        NaN
# 4                          NaN                 NaN       NaN        NaN
#
#   Gender Age range                             Self-defined ethnicity
# 0   Male     18-24                         White - White British (W1)  \
# 1   Male     18-24                         White - White British (W1)
# 2   Male     18-24  Black or Black British - Any other Black ethni...
# 3   Male       NaN                                    Not Stated (NS)
# 4   Male     18-24  Asian or Asian British - Any other Asian ethni...
#
#   Officer-defined ethnicity
# 0                     White  \
# 1                     White
# 2                     Black
# 3                     Black
# 4                     Asian
#
#                                          Legislation Object of search
# 0  Police and Criminal Evidence Act 1984 (section 1)              NaN  \
# 1  Police and Criminal Evidence Act 1984 (section 1)              NaN
# 2              Misuse of Drugs Act 1971 (section 23)              NaN
# 3              Misuse of Drugs Act 1971 (section 23)              NaN
# 4  Police and Criminal Evidence Act 1984 (section 1)              NaN
#
#                                    Outcome
# 0        Nothing found - no further action  \
# 1                         Suspect arrested
# 2  Offender given drugs possession warning
# 3        Nothing found - no further action
# 4        Nothing found - no further action
#
#    Outcome linked to object of search
# 0                                 NaN  \
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Removal of more than just outer clothing
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN

# %%
len(combined_data)
# Out:
# 1533196

# %%
combined_data.isna().sum()
# Out:
# Type                                              0
# Date                                              0
# Part of a policing operation                 178930
# Policing operation                          1533196
# Latitude                                     332993
# Longitude                                    332993
# Gender                                        18962
# Age range                                    174208
# Self-defined ethnicity                        18317
# Officer-defined ethnicity                     29193
# Legislation                                       0
# Object of search                              89451
# Outcome                                           0
# Outcome linked to object of search          1533196
# Removal of more than just outer clothing    1533196
# dtype: int64

# %%
combined_data = combined_data.dropna(subset=['Longitude'])

# %%
dropping_columns = ['Legislation']

# %%
combined_data.drop(columns=dropping_columns, inplace=True)

# %%
combined_data.to_parquet('stopandsearch.paraquet')
